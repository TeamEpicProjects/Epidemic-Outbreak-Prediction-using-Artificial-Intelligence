# %%
try:
    from wwo_hist import retrieve_hist_data
    import mysql.connector as connect
    import pandas as pd
    import os
    import time
    import datetime
    from glob import glob
    print("All modules are ok ......")
except Exception as e:
    print("Error  {} ".format(e))
# Out:
# All modules are ok ......

# %%
# # def extract_data():
# #     '''Extract the weather data from an api using wwo_hist library'''
# #     # country name with start date and end date
# #     lst = ['Ecuador-Caar', 'Ecuador-Cañar']

# #     os.chdir('weather_ecuador')
# #     frequency = 24
# #     api_key = '9a73f2a409a6434dac060137210909'

# #     # 9553803d74114abe82a83637212708
# #     # 6d12673d960d4c77a43183925210809
# #     # aea0e4414ebb4ac99e6192522210809
# #     # 9a73f2a409a6434dac060137210909

# #     # iterate all country name from dictionary
# #     for i in lst:
# #         time.sleep(5)
# #         start_date = '2016-03-30'
# #         end_date = '2017-11-15'

# #         location_list = [i]
# #         hist_weather_data = retrieve_hist_data(api_key,
# #                                         location_list,
# #                                         start_date,
# #                                         end_date,
# #                                         frequency,
# #                                         location_label = False,
# #                                         export_csv=True,
# #                                         store_df = True)
# # extract_data()

# def extract_data():
#     '''Extract the weather data from an api using wwo_hist library'''
#     # country name with start date and end date
#     country_name = {#  'Colombia-Risaralda-La_Celia': ['2016-01-09', '2016-12-31'],
#  'Colombia-Risaralda-La_Virginia': ['2016-01-09', '2016-12-31'],
#  'Colombia-Putumayo-Puerto_Guzman': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Labateca': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Los_Patios': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Lourdes': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Mutiscua': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Ocana': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Pamplona': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Pamplonita': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Puerto_Santander': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Ragonvalia': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-La_Playa': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-El_Carmen': ['2016-01-09', '2016-12-31'],
#  'Colombia-Cundinamarca-Fomeque': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-El_Zulia': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Gramalote': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Hacari': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Herran': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-La_Esperanza': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Salazar': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Villa_Caro': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Villa_Del_Rosario': ['2016-01-09', '2016-12-31'],
#  'Colombia-Putumayo-Colon': ['2016-01-09', '2016-12-31'],
#  'Colombia-Putumayo-Leguizamo': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Unknown': ['2016-01-09', '2016-12-31'],
#  'Colombia-Putumayo-Mocoa': ['2016-01-09', '2016-12-31'],
#  'Colombia-Putumayo-Orito': ['2016-01-09', '2016-12-31'],
#  'Colombia-Putumayo-Puerto_Asis': ['2016-01-09', '2016-12-31'],
#  'Colombia-Putumayo-Puerto_Caicedo': ['2016-01-09', '2016-12-31'],
#  'Colombia-San_Andres-San_Andres': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Toledo': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-San_Calixto': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-San_Cayetano': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Santiago': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Sardinata': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Silos': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Teorama': ['2016-01-09', '2016-12-31'],
#  'Colombia-Norte_Santander-Tibu': ['2016-01-09', '2016-12-31']
#     }


#     os.chdir('weather_colombia')

#     frequency = 24
#     api_key = '9a73f2a409a6434dac060137210909'

# #     api_key = 'c8d2b59b548f4be792c162118210809' Time out
# #     api_key = '1868d8144b8b4a03aba180122210809' Time out
# #     api_key = 'aea0e4414ebb4ac99e6192522210809' Time out
# #     api_key = '7e99654be68a47c5823185332210809' Time out
# #     api_key = 'dd41990b4a644d97a1b45027210909'  Time out
# #     api_key = '092a2ffeb04645c5ba855736210909'  Time out

#     # iterate all country name from dictionary
#     for i in country_name:
#         time.sleep(5)
#         start_date = country_name[i][0]
#         end_date = country_name[i][1]

#         location_list = [i]
#         hist_weather_data = retrieve_hist_data(api_key,
#                                         location_list,
#                                         start_date,
#                                         end_date,
#                                         frequency,
#                                         location_label = False,
#                                         export_csv=True)
# extract_data()

def extract_data():
    '''Extract the weather data from an api using wwo_hist library'''
    # country name with start date and end date
    country_name = ['Colombia-Narino-Consaca',
       'Colombia-Narino-Francisco_Pizarro', 'Colombia-Narino-La_Llanada',
       'Colombia-Narino-La_Tola', 'Colombia-Narino-La_Union',
       'Colombia-Narino-Leiva', 'Colombia-Narino-Linares',
       'Colombia-Narino-Los_Andes', 'Colombia-Narino-Magsi',
       'Colombia-Narino-Mallama', 'Colombia-Narino-La_Florida',
       'Colombia-Narino-Funes', 'Colombia-Narino-Guachucal',
       'Colombia-Narino-Guaitarilla', 'Colombia-Narino-Gualmatan',
       'Colombia-Narino-Iles', 'Colombia-Narino-Imues',
       'Colombia-Narino-Ipiales', 'Colombia-Narino-La_Cruz',
       'Colombia-Huila-Saladoblanco', 'Colombia-Huila-Pital',
       'Colombia-Cundinamarca-Ricaurte',
       'Colombia-Cundinamarca-San_Antonio_Del_Tequendama',
       'Colombia-Cundinamarca-San_Bernardo',
       'Colombia-Cundinamarca-San_Cayetano',
       'Colombia-Cundinamarca-San_Francisco',
       'Colombia-Cundinamarca-San_Juan_De_Rio_Seco',
       'Colombia-Cundinamarca-Sasaima', 'Colombia-Cundinamarca-Sesquile',
       'Colombia-Cundinamarca-Quipile', 'Colombia-Cundinamarca-Paime',
       'Colombia-Cundinamarca-Pandi', 'Colombia-Cundinamarca-Paratebueno',
       'Colombia-Cundinamarca-Pasca', 'Colombia-Cundinamarca-Sibate',
       'Colombia-Cundinamarca-Puerto_Salgar', 'Colombia-Cundinamarca-Puli',
       'Colombia-Cundinamarca-Quebradanegra', 'Colombia-Cundinamarca-Quetame',
       'Colombia-Cundinamarca-Pacho', 'Colombia-Cundinamarca-Silvania',
       'Colombia-Cundinamarca-Tabio', 'Colombia-Cundinamarca-Tausa',
       'Colombia-Cundinamarca-Tena', 'Colombia-Cundinamarca-Tenjo',
       'Colombia-Cundinamarca-Tibacuy', 'Colombia-Cundinamarca-Tibirita',
       'Colombia-Cundinamarca-Tocaima', 'Colombia-Cundinamarca-Tocancipa',
       'Colombia-Cundinamarca-Topaipi', 'Colombia-Cundinamarca-Sutatausa',
       'Colombia-Cundinamarca-Simijaca', 'Colombia-Cundinamarca-Soacha',
       'Colombia-Cundinamarca-Sopo', 'Colombia-Cundinamarca-Subachoque',
       'Colombia-Cundinamarca-Suesca', 'Colombia-Cundinamarca-Supata',
       'Colombia-Cundinamarca-Susa', 'Colombia-Cundinamarca-Nocaima',
       'Colombia-Cundinamarca-Granada', 'Colombia-Cundinamarca-Guacheta',
       'Colombia-Cundinamarca-Guaduas', 'Colombia-Cundinamarca-Guasca',
       'Colombia-Cundinamarca-Guataqui', 'Colombia-Cundinamarca-Guatavita',
       'Colombia-Cundinamarca-Guayabal_De_Siquima',
       'Colombia-Cundinamarca-Guayabetal', 'Colombia-Cundinamarca-Girardot',
       'Colombia-Cundinamarca-Fosca', 'Colombia-Cundinamarca-Funza',
       'Colombia-Cundinamarca-Fuquene', 'Colombia-Cundinamarca-Fusagasuga',
       'Colombia-Cundinamarca-Gutierrez', 'Colombia-Cundinamarca-Gachala',
       'Colombia-Cundinamarca-Gachancipa', 'Colombia-Cundinamarca-Gacheta',
       'Colombia-Cundinamarca-Gama']

    os.chdir('weather_colombia1')

    frequency = 24
    api_key = 'a0077fd8271d4860858121052210909'
    # a0077fd8271d4860858121052210909
    # b0706f7aa8f94c66a76104251210909

    # iterate all country name from dictionary
    for i in country_name:
        time.sleep(5)
        start_date = '2016-01-02'
        end_date = '2016-01-02'

        location_list = [i]
        hist_weather_data = retrieve_hist_data(api_key,
                                        location_list,
                                        start_date,
                                        end_date,
                                        frequency,
                                        location_label = False,
                                        export_csv=True)
extract_data()
# Out:
# Retrieving weather data for Colombia-Narino-Consaca
#
#
# Currently retrieving data for Colombia-Narino-Consaca: from 2016-01-02 to 2016-01-02
# Time elapsed (hh:mm:ss.ms) 0:00:00.736005
#
#
# export Colombia-Narino-Consaca completed!
#
#
#
#
# Retrieving weather data for Colombia-Narino-Francisco_Pizarro
#
#
# Currently retrieving data for Colombia-Narino-Francisco_Pizarro: from 2016-01-02 to 2016-01-02
# Time elapsed (hh:mm:ss.ms) 0:00:00.463935
#
#
# export Colombia-Narino-Francisco_Pizarro completed!
#
#
#
#
# Retrieving weather data for Colombia-Narino-La_Llanada
#
#
# Currently retrieving data for Colombia-Narino-La_Llanada: from 2016-01-02 to 2016-01-02
# Time elapsed (hh:mm:ss.ms) 0:00:00.416007
#
#
# export Colombia-Narino-La_Llanada completed!
#
#
#
#
# Retrieving weather data for Colombia-Narino-La_Tola
#
#
# Currently retrieving data for Colombia-Narino-La_Tola: from 2016-01-02 to 2016-01-02
# Time elapsed (hh:mm:ss.ms) 0:00:00.472001
#
#
# ...

# %%
stock_files = sorted(glob('*.csv'))
print(stock_files)
data = pd.concat((pd.read_csv(file, encoding='cp1252')
                      for file in stock_files), ignore_index=True)
data.to_csv("colombia1_weather.csv",index=False)
print("Success...")
# Out:
# ['Colombia-Cundinamarca-Fosca.csv', 'Colombia-Cundinamarca-Funza.csv', 'Colombia-Cundinamarca-Fuquene.csv', 'Colombia-Cundinamarca-Fusagasuga.csv', 'Colombia-Cundinamarca-Gachala.csv', 'Colombia-Cundinamarca-Gachancipa.csv', 'Colombia-Cundinamarca-Gacheta.csv', 'Colombia-Cundinamarca-Gama.csv', 'Colombia-Cundinamarca-Girardot.csv', 'Colombia-Cundinamarca-Granada.csv', 'Colombia-Cundinamarca-Guacheta.csv', 'Colombia-Cundinamarca-Guaduas.csv', 'Colombia-Cundinamarca-Guasca.csv', 'Colombia-Cundinamarca-Guataqui.csv', 'Colombia-Cundinamarca-Guatavita.csv', 'Colombia-Cundinamarca-Guayabal_De_Siquima.csv', 'Colombia-Cundinamarca-Guayabetal.csv', 'Colombia-Cundinamarca-Gutierrez.csv', 'Colombia-Cundinamarca-Nocaima.csv', 'Colombia-Cundinamarca-Pacho.csv', 'Colombia-Cundinamarca-Paime.csv', 'Colombia-Cundinamarca-Pandi.csv', 'Colombia-Cundinamarca-Paratebueno.csv', 'Colombia-Cundinamarca-Pasca.csv', 'Colombia-Cundinamarca-Puerto_Salgar.csv', 'Colombia-Cundinamarca-Puli.csv', 'Colombia-Cundin
# ...
