# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import re
import datetime

import matplotlib.style as style
# %matplotlib inline
style.use('ggplot')

import warnings
warnings.simplefilter("ignore")

pd.pandas.set_option('display.max_columns',None)

# %%
weather = pd.read_csv('04_weekly_weather.csv')
# Convert our report_date columns to datetime datatype
weather['date'] = pd.to_datetime(weather['date'], format="%Y-%m-%d")

# create new year and month column from datetime
weather['year'] = pd.DatetimeIndex(weather['date']).year
weather['month'] = pd.DatetimeIndex(weather['date']).month

# %%
zika = pd.read_csv('zikavirus.csv')

# filter out those rows which does not contain any data
zika = zika.dropna(how = 'all')
  
# Filter all rows for which the report_date is equal to 18437
zika.drop(zika[zika['report_date'] == '18437'].index, inplace = True)

# covert string to an float
zika['cases'] = zika['cases'].astype(float)

# Replace nan value with 0,
zika['cases'] = zika['cases'].fillna(0)

# covert float to an int
zika['cases'] = zika['cases'].astype(int)

# Convert our report_date columns to datetime datatype
zika['report_date'] = pd.to_datetime(zika['report_date'], format="%Y-%m-%d")

# create new year and month column from datetime
zika['year'] = pd.DatetimeIndex(zika['report_date']).year
zika['month'] = pd.DatetimeIndex(zika['report_date']).month

# %% [markdown]
# # 1 Nicaragua

# %%
nica_zika = zika[zika["location"].str.startswith("Nicaragua")]
nica_zika.head()
# Out:
#        report_date                        location location_type  \
# 226671  2016-02-09                       Nicaragua       country
# 226672  2016-02-09                       Nicaragua       country
# 226673  2016-02-09  Nicaragua-Nueva_Segovia-Ocotal  municipality
# 226674  2016-02-09   Nicaragua-Managua-Distrito_II      district
# 226675  2016-02-09                       Nicaragua       country
#
#                              data_field  cases    year  month
# 226671         total_zika_new_suspected      5  2016.0    2.0
# 226672             total_zika_confirmed      3  2016.0    2.0
# 226673             total_zika_confirmed      1  2016.0    2.0
# 226674             total_zika_confirmed      2  2016.0    2.0
# 226675  total_zika_confirmed_cumulative     41  2016.0    2.0

# %%
nica_zika.shape
# Out:
# (207, 7)

# %% [markdown]
# ### 1.1 Data fields

# %%
nica_zika.data_field.unique()
# Out:
# array(['total_zika_new_suspected', 'total_zika_confirmed',
#        'total_zika_confirmed_cumulative',
#        'total_zika_confirmed_pregnant_cumulative',
#        'total_zika_confirmed_pregnant', 'normal_birth_confirmed_zika',
#        'normal_birth_confirmed_cumulative'], dtype=object)

# %%
nica_zika.location_type.unique()
# Out:
# array(['country', 'municipality', 'district', 'city'], dtype=object)

# %%
nicaraguaCases = nica_zika.loc[(nica_zika['data_field'] == 'total_zika_confirmed') & (nica_zika['location_type'] == 'country')]
nicaraguaCases = nicaraguaCases.sort_values(by=['report_date'])
nicaraguaCases
# Out:
#        report_date   location location_type            data_field  cases  \
# 226672  2016-02-09  Nicaragua       country  total_zika_confirmed      3
# 226677  2016-02-11  Nicaragua       country  total_zika_confirmed      4
# 226683  2016-02-12  Nicaragua       country  total_zika_confirmed      6
# 226691  2016-02-15  Nicaragua       country  total_zika_confirmed     27
# 226694  2016-02-16  Nicaragua       country  total_zika_confirmed      1
# 226761  2016-02-22  Nicaragua       country  total_zika_confirmed     12
# 226763  2016-02-23  Nicaragua       country  total_zika_confirmed      2
# 226834  2016-03-07  Nicaragua       country  total_zika_confirmed     12
# 226847  2016-03-11  Nicaragua       country  total_zika_confirmed      2
# 226830  2016-03-11  Nicaragua       country  total_zika_confirmed      2
# 226851  2016-03-14  Nicaragua       country  total_zika_confirmed     15
# 226858  2016-03-16  Nicaragua       country  total_zika_confirmed      4
# 226863  2016-03-28  Nicaragua       country  total_zika_confirmed      5
# 226867  2016-04-04  Nicaragua       country  total_zika_confirmed      2
# 226871  2016-04-18  Nicaragua       country  total_zika_confirmed      2
# 226875  2016-04-25  Nicaragua       country  total_zika_confirmed     11
# 226699  2016-05-04  Nicaragua       country  total_zika_confirmed     12
# 226703  2016-05-05  Nicaragua       country  total_zika_confirmed      3
# 226730  2016-06-03  Nicaragua       country  total_zika_confirmed      5
# 226734  2016-06-13  Nicaragua       country  total_zika_confirmed     16
# 226737  2016-06-17  Nicaragua       country  total_zika_confirmed     26
# 226741  2016-06-20  Nicaragua       country  total_zika_confirmed     29
# 226745  2016-06-22  Nicaragua       country  total_zika_confirmed      8
# 226747  2016-06-23  Nicaragua       country  total_zika_confirmed      1
# 226750  2016-06-27  Nicaragua       country  total_zika_confirmed     18
# 226751  2016-06-29  Nicaragua       country  total_zika_confirmed      3
# 226752  2016-07-01  Nicaragua       country  total_zika_confirmed     13
# 226756  2016-07-04  Nicaragua       country  total_zika_confirmed     62
# 226767  2016-07-11  Nicaragua       country  total_zika_confirmed     28
# 226768  2016-07-25  Nicaragua       country  total_zika_confirmed     76
# 226773  2016-08-02  Nicaragua       country  total_zika_confirmed    213
# 226780  2016-08-03  Nicaragua       country  total_zika_confirmed     17
# 226781  2016-08-05  Nicaragua       country  total_zika_confirmed     51
# 226784  2016-08-08  Nicaragua       country  total_zika_confirmed    191
# 226795  2016-08-12  Nicaragua       country  total_zika_confirmed     53
# 226797  2016-08-15  Nicaragua       country  total_zika_confirmed    104
# 226805  2016-08-17  Nicaragua       country  total_zika_confirmed     42
# 226806  2016-08-29  Nicaragua       country  total_zika_confirmed    150
# 226808  2016-09-05  Nicaragua       country  total_zika_confirmed    103
# 226814  2016-09-06  Nicaragua       country  total_zika_confirmed      8
# 226819  2016-09-19  Nicaragua       country  total_zika_confirmed     47
# 226822  2016-09-20  Nicaragua       country  total_zika_confirmed      8
#
#           year  month
# 226672  2016.0    2.0
# 226677  2016.0    2.0
# 226683  2016.0    2.0
# 226691  2016.0    2.0
# 226694  2016.0    2.0
# 226761  2016.0    2.0
# 226763  2016.0    2.0
# 226834  2016.0    3.0
# 226847  2016.0    3.0
# 226830  2016.0    3.0
# 226851  2016.0    3.0
# 226858  2016.0    3.0
# 226863  2016.0    3.0
# 226867  2016.0    4.0
# 226871  2016.0    4.0
# 226875  2016.0    4.0
# 226699  2016.0    5.0
# 226703  2016.0    5.0
# 226730  2016.0    6.0
# 226734  2016.0    6.0
# 226737  2016.0    6.0
# 226741  2016.0    6.0
# 226745  2016.0    6.0
# 226747  2016.0    6.0
# 226750  2016.0    6.0
# 226751  2016.0    6.0
# 226752  2016.0    7.0
# 226756  2016.0    7.0
# 226767  2016.0    7.0
# 226768  2016.0    7.0
# 226773  2016.0    8.0
# 226780  2016.0    8.0
# 226781  2016.0    8.0
# 226784  2016.0    8.0
# 226795  2016.0    8.0
# 226797  2016.0    8.0
# 226805  2016.0    8.0
# 226806  2016.0    8.0
# 226808  2016.0    9.0
# 226814  2016.0    9.0
# 226819  2016.0    9.0
# 226822  2016.0    9.0

# %% [markdown]
# ### 1.2 Country wise cases

# %%
# Countries with zero case
total_cases = nicaraguaCases.groupby(['location']).cases.agg([sum])
total_cases.sort_values('sum', ascending=False).head()
# Out:
#             sum
# location
# Nicaragua  1397

# %%
# remove countries with zero case
cases = total_cases[total_cases['sum'] == 0]
cases.index
# Out:
# Index([], dtype='object', name='location')

# %% [markdown]
# ### 1.3 Analyse the pattern of spreading virus  in Nicaragua

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x='report_date', y='cases', hue='year',data=nicaraguaCases,palette=['green'])
plt.title('Nicaragua virus cases')
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x='month', y='cases', hue='year',data=nicaraguaCases, palette=['green'] )
plt.title('Nicaragua')
plt.xlabel('Month')
plt.ylabel('Zikavirus cases')
plt.show()

# %% [markdown]
# Let's analyse the confirmed cases of zika virus with three environmental factors such as max temperature, precipitation and humidity. And also considering the incubation period 3–14 days.

# %% [markdown]
# ### 1.5 Analysis the weather of Nicaragua

# %%
nicaragua = nicaraguaCases.groupby(['report_date']).cases.agg([sum])
nicaragua = nicaragua.reset_index()
nicaragua
# Out:
#    report_date  sum
# 0   2016-02-09    3
# 1   2016-02-11    4
# 2   2016-02-12    6
# 3   2016-02-15   27
# 4   2016-02-16    1
# 5   2016-02-22   12
# 6   2016-02-23    2
# 7   2016-03-07   12
# 8   2016-03-11    4
# 9   2016-03-14   15
# 10  2016-03-16    4
# 11  2016-03-28    5
# 12  2016-04-04    2
# 13  2016-04-18    2
# 14  2016-04-25   11
# 15  2016-05-04   12
# 16  2016-05-05    3
# 17  2016-06-03    5
# 18  2016-06-13   16
# 19  2016-06-17   26
# 20  2016-06-20   29
# 21  2016-06-22    8
# 22  2016-06-23    1
# 23  2016-06-27   18
# 24  2016-06-29    3
# 25  2016-07-01   13
# 26  2016-07-04   62
# 27  2016-07-11   28
# 28  2016-07-25   76
# 29  2016-08-02  213
# 30  2016-08-03   17
# 31  2016-08-05   51
# 32  2016-08-08  191
# 33  2016-08-12   53
# 34  2016-08-15  104
# 35  2016-08-17   42
# 36  2016-08-29  150
# 37  2016-09-05  103
# 38  2016-09-06    8
# 39  2016-09-19   47
# 40  2016-09-20    8

# %% [markdown]
# ### 1.7 Nicaragua Weather

# %%
NicaraguaWeather = pd.read_csv('weatherdataset.csv')
NicaraguaWeather = NicaraguaWeather[NicaraguaWeather["location"].str.startswith("Nicaragua")]
NicaraguaWeather.head()
# Out:
#        date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 4648  2016-02-09        33        23           0.0      8.7        7
# 4649  2016-02-10        32        22           0.0      8.7        7
# 4650  2016-02-11        33        22           0.0      8.7        7
# 4651  2016-02-12        34        23           0.0      8.7        7
# 4652  2016-02-13        35        23           0.0      8.7        8
#
#       moon_illumination  moonrise   moonset   sunrise    sunset  DewPointC  \
# 4648                  4  06:53 AM  07:05 PM  06:09 AM  05:50 PM         16
# 4649                 12  07:44 AM  08:03 PM  06:08 AM  05:50 PM         14
# 4650                 19  08:33 AM  09:01 PM  06:08 AM  05:51 PM         15
# 4651                 27  09:23 AM  09:59 PM  06:08 AM  05:51 PM         17
# 4652                 34  10:12 AM  10:56 PM  06:07 AM  05:51 PM         18
#
#       FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 4648          28          28          27            35          21        52
# 4649          27          27          26            39          18        49
# 4650          28          28          26            38          18        52
# 4651          29          29          28            39          15        54
# 4652          30          30          28            42          13        56
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 4648       0.0      1014     33          10             65             26
# 4649       0.0      1015     32          10             60             29
# 4650       0.0      1014     33          10             66             29
# 4651       0.0      1013     34          10             65             29
# 4652       0.0      1012     35          10             60             31
#
#        location
# 4648  Nicaragua
# 4649  Nicaragua
# 4650  Nicaragua
# 4651  Nicaragua
# 4652  Nicaragua

# %%
# Convert our report_date columns to datetime datatype
NicaraguaWeather['date_time'] = pd.to_datetime(NicaraguaWeather['date_time'], format="%Y-%m-%d")

# create new year and month column from datetime
NicaraguaWeather['year'] = pd.DatetimeIndex(NicaraguaWeather['date_time']).year
NicaraguaWeather['month'] = pd.DatetimeIndex(NicaraguaWeather['date_time']).month

# %% [markdown]
# ### Case 1
# * Report date - 2016-02-15 = 27
# * weather date - 2016-02-09 to 	2016-02-15

# %%
nica_case1 = NicaraguaWeather.loc[(NicaraguaWeather['date_time'] >= '2016-02-09 ') & (NicaraguaWeather['date_time'] <= ' 2016-02-15')]
fig, axes = plt.subplots(3,1, figsize=(15, 15))
sns.lineplot(ax=axes[0],x='date_time',y='maxtempC',data=nica_case1)
axes[0].set_title('Max temperature')
sns.lineplot(ax=axes[1],x='date_time',y='precipMM',data=nica_case1)
axes[1].set_title('Precipitaion')
sns.lineplot(ax=axes[2],x='date_time',y='humidity',data=nica_case1)
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# ### Case 2
# * Report date - 2016-06-23 = 1
# * weather date - 2016-06-09  to 2016-06-23

# %%
nica_case2 = NicaraguaWeather.loc[(NicaraguaWeather['date_time'] >= '2016-06-09') & (NicaraguaWeather['date_time'] <= '2016-06-23')]
fig, axes = plt.subplots(3,1, figsize=(15, 15))
sns.lineplot(ax=axes[0],x='date_time',y='maxtempC',data=nica_case2)
axes[0].set_title('Max temperature')
sns.lineplot(ax=axes[1],x='date_time',y='precipMM',data=nica_case2)
axes[1].set_title('Precipitaion')
sns.lineplot(ax=axes[2],x='date_time',y='humidity',data=nica_case2)
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# ### Case 3
# * Report date - 2016-08-02 = 213
# * weather date - 2016-07-19  to 2016-08-02

# %%
nica_case3 = NicaraguaWeather.loc[(NicaraguaWeather['date_time'] >= '2016-07-19') & (NicaraguaWeather['date_time'] <= '2016-08-02')]
fig, axes = plt.subplots(3,1, figsize=(15, 15))
sns.lineplot(ax=axes[0],x='date_time',y='maxtempC',data=nica_case3)
axes[0].set_title('Max temperature')
sns.lineplot(ax=axes[1],x='date_time',y='precipMM',data=nica_case3)
axes[1].set_title('Precipitaion')
sns.lineplot(ax=axes[2],x='date_time',y='humidity',data=nica_case3)
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %%
fig, axes = plt.subplots(3,1, figsize=(15, 15))
sns.lineplot(ax=axes[0],x='date_time',y='maxtempC',data=NicaraguaWeather)
axes[0].set_title('Max temperature')
sns.lineplot(ax=axes[1],x='date_time',y='precipMM',data=NicaraguaWeather)
axes[1].set_title('Precipitaion')
sns.lineplot(ax=axes[2],x='date_time',y='humidity',data=NicaraguaWeather)
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %%
nicaragua_cases = nicaragua.rename(columns={"report_date": "date_time"})
NicaraguaWeather = NicaraguaWeather[['date_time','maxtempC','precipMM','humidity']]
nicaragua_case = pd.merge(nicaragua_cases,NicaraguaWeather, on=['date_time'], how='left') 
nicaragua_case.head()
# Out:
#    date_time  sum  maxtempC  precipMM  humidity
# 0 2016-02-09    3        33       0.0        52
# 1 2016-02-11    4        33       0.0        52
# 2 2016-02-12    6        34       0.0        54
# 3 2016-02-15   27        34       0.1        60
# 4 2016-02-16    1        36       0.0        59

# %%
fig, axes = plt.subplots(1,3, figsize=(15, 4))
sns.regplot(ax=axes[0],y=nicaragua_case['maxtempC'], x=nicaragua_case['sum'])
axes[0].set_title('Max temperature')
sns.regplot(ax=axes[1],y=nicaragua_case['precipMM'], x=nicaragua_case['sum'])
axes[1].set_title('Precipitaion')
sns.regplot(ax=axes[2],y=nicaragua_case['humidity'], x=nicaragua_case['sum'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %%
sns.heatmap(nicaragua_case.corr(),cmap='Blues',annot=True,vmax=1,vmin=-1)
