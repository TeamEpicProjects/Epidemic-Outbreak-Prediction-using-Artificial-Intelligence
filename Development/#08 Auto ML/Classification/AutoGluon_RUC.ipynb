# %%
# !pip install autogluon.tabular[all]

# %%
# import libraries
from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
# load dataset
df = pd.read_csv('../input/zikavirusdataset/classification_dataset.csv')
df.head()
# Out:
#    density_per_km   latitude  longitude  maxtempC  mintempC  totalSnow_cm  \
# 0    12625.800781 -34.603684 -58.381559        24         7           0.0
# 1    12625.800781 -34.603684 -58.381559        24         7           0.0
# 2    12625.800781 -34.603684 -58.381559        24         7           0.0
# 3    12625.800781 -34.603684 -58.381559        24         7           0.0
# 4    12625.800781 -34.603684 -58.381559        22        10           0.0
#
#    sunHour  moon_illumination  DewPointC  WindGustKmph  cloudcover  humidity  \
# 0     11.6                 87          6            16           0        59
# 1     11.6                 87          6            16           0        59
# 2     11.6                 87          6            16           0        59
# 3     11.6                 87          6            16           0        59
# 4     11.5                 76         10            27          34        72
#
#    precipMM  pressure  visibility  winddirDegree  year  month  Target
# 0       0.0      1018          10            189  2016      3       1
# 1       0.0      1018          10            189  2016      3       0
# 2       0.0      1018          10            189  2016      3       1
# 3       0.0      1018          10            189  2016      3       0
# 4       0.0      1025          10             99  2016      3       0

# %%
# Rows and cols
df.shape
# Out:
# (155223, 19)

# %%
# toal duplicate values
df.duplicated().sum()
# Out:
# 79878

# %%
# Remove duplicate rows
df = df.drop_duplicates(keep='first', inplace=False)

# %%
df.shape
# Out:
# (75345, 19)

# %% [markdown]
# # Train Test Split

# %%
train_data,test_data = train_test_split(df,test_size=0.40,random_state=0,stratify=df['Target'] ) #train test split in 60:40 ratio

# %%
train_data.shape, test_data.shape
# Out:
# ((45207, 19), (30138, 19))

# %%
train_data['Target'].value_counts(), test_data['Target'].value_counts()
# Out:
# (0    24440
#  1    20767
#  Name: Target, dtype: int64,
#  0    16294
#  1    13844
#  Name: Target, dtype: int64)

# %% [markdown]
# # Build Model

# %%
label = 'Target'
metric = 'roc_auc'  # specify your evaluation metric here
predictor = TabularPredictor(label=label, eval_metric=metric).fit(train_data, presets='best_quality')
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# [1000]	train_set's binary_logloss: 0.196385	valid_set's binary_logloss: 0.271045
# [1000]	train_set's binary_logloss: 0.195602	valid_set's binary_logloss: 0.284641
# [2000]	train_set's binary_logloss: 0.145881	valid_set's binary_logloss: 0.282455
# [1000]	train_set's binary_logloss: 0.19601	valid_set's binary_logloss: 0.269292
# [2000]	train_set's binary_logloss: 0.145735	valid_set's binary_logloss: 0.268352
# [1000]	train_set's binary_logloss: 0.197759	valid_set's binary_logloss: 0.259421
# [2000]	train_set's binary_logloss: 0.148116	valid_set's binary_logloss: 0.257776
# [1000]	train_set's binary_logloss: 0.196463	valid_set's binary_logloss: 0.278958
# [1000]	train_set's binary_logloss: 0.197141	valid_set's binary_logloss: 0.269757
# [1000]	train_set's binary_logloss: 0.196839	valid_set's binary_logloss: 0.270652
# [2000]	train_set's binary_logloss: 0.147113	valid_set's binary_logloss: 0.268049
# [1000]	train_set's binary_logloss: 0.1961	valid_set's binary_logloss: 0.27684
# [2000]	train_set's binary_logloss: 0.146468	valid_set's binary_logloss: 0.275423
# [1000]	train_set's binary_logloss: 0.196529	valid_set's binary_logloss: 0.281031
# [2000]	train_set's binary_logloss: 0.14676	valid_set's binary_logloss: 0.279764
# [1000]	train_set's binary_logloss: 0.195697	valid_set's binary_logloss: 0.273072

# %%
results = predictor.fit_summary(show_plot=True)
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       WeightedEnsemble_L3   0.949720      37.210031  3214.693246                0.017724          19.351125            3       True         26
# 1   RandomForestGini_BAG_L2   0.947713      25.892469  1979.724148                1.967376          19.276930            2       True         17
# 2   RandomForestEntr_BAG_L2   0.947576      25.834585  1989.950431                1.909492          29.503213            2       True         18
# 3     ExtraTreesGini_BAG_L2   0.947308      26.276035  1965.778201                2.350942           5.330984            2       True         20
# 4     ExtraTreesEntr_BAG_L2   0.947140      26.215806  1966.597646                2.290713           6.150428            2       True         21
# 5      LightGBMLarge_BAG_L2   0.946680      24.380373  2018.434395                0.455280          57.987177            2       True         25
# 6           LightGBM_BAG_L2   0.946023      24.348277  1994.704804                0.423184          34.257587            2       True         16
# 7         LightGBMXT_BAG_L2   0.945452      26.662084  2088.459737                2.736991         128.012519            2       True         15
# 8            XGBoost_BAG_L2   0.944776      24.199243  1993.609966                0.274150          33.162748            2       True         23
# 9           CatBoost_BAG_L2   0.944689      24.021507  2072.585986                0.096414         112.138768            2       True         19
# 10   NeuralNetFastAI_BAG_L2   0.944223      25.167060  2863.852661                1.241967         903.405443            2       True         22
# 11    NeuralNetMXNet_BAG_L2   0.942457      27.795319  3042.835804                3.870226        1082.388586            2       True         24
# 12      WeightedEnsemble_L2   0.672252       1.540642   909.833842                0.017712          22.930977            2       True         14
# 13          LightGBM_BAG_L1   0.671102       0.234921    15.396821                0.234921          15.396821            1       True          4
# 14          CatBoost_BAG_L1   0.665181       0.076926   103.492475                0.076926         103.492475            1       True          7
# 15     LightGBMLarge_BAG_L1   0.662764       0.228082    20.823881                0.228082          20.823881            1       True         13
# 16   NeuralNetFastAI_BAG_L1   0.656675       1.059927   850.682163                1.059927         850.682163            1       True         10
# 17           XGBoost_BAG_L1   0.656357       0.198474    11.363792                0.198474          11.363792            1       True         11
# 18        LightGBMXT_BAG_L1   0.652824       0.460032    29.029012                0.460032          29.029012            1       True          3
# 19    NeuralNetMXNet_BAG_L1   0.630440       3.877782   877.250759                3.877782         877.250759            1       True         12
# 20    KNeighborsUnif_BAG_L1   0.494399       2.724805     0.194548                2.724805           0.194548            1       True          1
# 21  RandomForestEntr_BAG_L1   0.383472       2.755520    22.310024                2.755520          22.310024            1       True          6
# 22  RandomForestGini_BAG_L1   0.380056       2.675128    14.287951                2.675128          14.287951            1       True          5
# 23    ExtraTreesEntr_BAG_L1   0.347511       3.087351     8.128519                3.087351           8.128519            1       True          9
# 24    ExtraTreesGini_BAG_L1   0.346693       3.122340     7.322661                3.122340           7.322661            1       True          8
# 25    KNeighborsDist_BAG_L1   0.249756       3.423805     0.164611                3.423805           0.164611            1       True          2
# Number of models trained: 26
# Types of models trained:
# {'StackerEnsembleModel_XT', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_TabularNeuralNet', 'StackerEnsembleModel_XGBoost', 'WeightedEnsembleModel'}
# Bagging used: True  (with 10 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', []) :  6 | ['density_per_km', 'latitude', 'longitude', 'totalSnow_cm', 'sunHour', ...]
# ('int', [])   : 12 | ['maxtempC', 'mintempC', 'moon_illumination', 'DewPointC', 'WindGustKmph', ...]
# Plot summary of models saved to file: AutogluonModels/ag-20210921_175424/SummaryOfModels.html
# *** End of fit() summary ***

# %%
predictor.leaderboard(train_data, silent=True)
# Out:
#                       model  score_test  score_val  pred_time_test  \
# 0     KNeighborsDist_BAG_L1    0.906159   0.249756        3.381042
# 1   RandomForestEntr_BAG_L1    0.906159   0.383472        4.962452
# 2   RandomForestGini_BAG_L1    0.906159   0.380056        3.824811
# 3     ExtraTreesEntr_BAG_L1    0.906158   0.347511        6.283259
# 4     ExtraTreesGini_BAG_L1    0.906158   0.346693        5.759523
# 5      LightGBMLarge_BAG_L1    0.754929   0.662764        4.378022
# 6     KNeighborsUnif_BAG_L1    0.741008   0.494399        3.482374
# 7            XGBoost_BAG_L1    0.732267   0.656357        1.560439
# 8           CatBoost_BAG_L1    0.731273   0.665181        0.320601
# 9           LightGBM_BAG_L1    0.728489   0.671102        5.371019
# 10      WeightedEnsemble_L2    0.725258   0.672252       21.753297
# 11        LightGBMXT_BAG_L1    0.712213   0.652824        5.875743
# 12    NeuralNetMXNet_BAG_L1    0.686885   0.630440       16.583364
# 13   NeuralNetFastAI_BAG_L1    0.686649   0.656675       11.998319
# 14    ExtraTreesEntr_BAG_L2    0.284497   0.947140       75.734958
# 15    ExtraTreesGini_BAG_L2    0.284352   0.947308       76.313498
# 16  RandomForestEntr_BAG_L2    0.261835   0.947576       75.484921
# 17  RandomForestGini_BAG_L2    0.259492   0.947713       75.730282
# 18    NeuralNetMXNet_BAG_L2    0.255027   0.942457       88.674450
# 19        LightGBMXT_BAG_L2    0.254568   0.945452      101.712068
# 20      WeightedEnsemble_L3    0.253118   0.949720      104.965215
# 21   NeuralNetFastAI_BAG_L2    0.211845   0.944223       85.228631
# 22          CatBoost_BAG_L2    0.209430   0.944689       74.109929
# 23           XGBoost_BAG_L2    0.202575   0.944776       76.001445
# 24          LightGBM_BAG_L2    0.177831   0.946023       77.994577
# 25     LightGBMLarge_BAG_L2    0.174765   0.946680       77.710244
#
#     pred_time_val     fit_time  pred_time_test_marginal  \
# 0        3.423805     0.164611                 3.381042
# 1        2.755520    22.310024                 4.962452
# 2        2.675128    14.287951                 3.824811
# 3        3.087351     8.128519                 6.283259
# 4        3.122340     7.322661                 5.759523
# 5        0.228082    20.823881                 4.378022
# 6        2.724805     0.194548                 3.482374
# 7        0.198474    11.363792                 1.560439
# 8        0.076926   103.492475                 0.320601
# 9        0.234921    15.396821                 5.371019
# 10       1.540642   909.833842                 0.005936
# 11       0.460032    29.029012                 5.875743
# 12       3.877782   877.250759                16.583364
# 13       1.059927   850.682163                11.998319
# 14      26.215806  1966.597646                 1.953991
# 15      26.276035  1965.778201                 2.532531
# 16      25.834585  1989.950431                 1.703954
# 17      25.892469  1979.724148                 1.949315
# 18      27.795319  3042.835804                14.893482
# 19      26.662084  2088.459737                27.931100
# 20      37.210031  3214.693246                 0.008089
# 21      25.167060  2863.852661                11.447664
# 22      24.021507  2072.585986                 0.328962
# 23      24.199243  1993.609966                 2.220477
# 24      24.348277  1994.704804                 4.213610
# 25      24.380373  2018.434395                 3.929277
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 3.423805           0.164611            1       True
# 1                 2.755520          22.310024            1       True
# 2                 2.675128          14.287951            1       True
# 3                 3.087351           8.128519            1       True
# 4                 3.122340           7.322661            1       True
# 5                 0.228082          20.823881            1       True
# 6                 2.724805           0.194548            1       True
# 7                 0.198474          11.363792            1       True
# 8                 0.076926         103.492475            1       True
# 9                 0.234921          15.396821            1       True
# 10                0.017712          22.930977            2       True
# 11                0.460032          29.029012            1       True
# 12                3.877782         877.250759            1       True
# 13                1.059927         850.682163            1       True
# 14                2.290713           6.150428            2       True
# 15                2.350942           5.330984            2       True
# 16                1.909492          29.503213            2       True
# 17                1.967376          19.276930            2       True
# 18                3.870226        1082.388586            2       True
# 19                2.736991         128.012519            2       True
# 20                0.017724          19.351125            3       True
# 21                1.241967         903.405443            2       True
# 22                0.096414         112.138768            2       True
# 23                0.274150          33.162748            2       True
# 24                0.423184          34.257587            2       True
# 25                0.455280          57.987177            2       True
#
#     fit_order
# 0           2
# 1           6
# 2           5
# 3           9
# 4           8
# 5          13
# 6           1
# 7          11
# 8           7
# 9           4
# 10         14
# 11          3
# 12         12
# 13         10
# 14         21
# 15         20
# 16         18
# 17         17
# 18         24
# 19         15
# 20         26
# 21         22
# 22         19
# 23         23
# 24         16
# 25         25

# %% [markdown]
# # Make Prediction

# %%
y_test = test_data[label]  # values to predict
test_data_nolab = test_data.drop(columns=[label])  # delete label column to prove we're not cheating
test_data_nolab.head()
# Out:
#         density_per_km   latitude  longitude  maxtempC  mintempC  \
# 85860        49.728394   4.156630 -76.287762        27        16
# 50844        59.433132   9.144527 -74.226294        31        23
# 138749      209.804016  15.594288 -90.149499        30        17
# 107305      147.182251  19.052706 -70.149226        27        18
# 154932      835.046448  18.335765 -64.896335        28        27
#
#         totalSnow_cm  sunHour  moon_illumination  DewPointC  WindGustKmph  \
# 85860            0.0     12.5                 59         14             5
# 50844            0.0     11.9                100         24             8
# 138749           0.0     13.0                 84         17             7
# 107305           0.0      6.2                 64         19             8
# 154932           0.0      8.7                 96         23            41
#
#         cloudcover  humidity  precipMM  pressure  visibility  winddirDegree  \
# 85860           18        68      16.6      1015           9            207
# 50844           57        85       6.2      1010           7            229
# 138749          13        74       1.0      1012           8            140
# 107305          77        82       1.5      1016           7            158
# 154932          42        77      12.9      1017           9             82
#
#         year  month
# 85860   2016      9
# 50844   2016      5
# 138749  2016      5
# 107305  2016      4
# 154932  2016     12

# %%
predictor = TabularPredictor.load('./AutogluonModels/ag-20210921_175424')  # unnecessary, just demonstrates how to load previously-trained predictor from file

y_pred = predictor.predict(test_data_nolab)
print("Predictions:  \n", y_pred)
# Out:
# Predictions:
#  85860     0
# 50844     1
# 138749    1
# 107305    0
# 154932    1
#          ..
# 76754     1
# 50884     1
# 141791    0
# 22127     1
# 60368     0
# Name: Target, Length: 30138, dtype: int64

# %%
predictor.leaderboard(test_data, silent=True)
# Out:
#                       model  score_test  score_val  pred_time_test  \
# 0    NeuralNetFastAI_BAG_L2    0.944730   0.944223       47.756374
# 1           LightGBM_BAG_L2    0.944463   0.946023       42.513519
# 2           CatBoost_BAG_L2    0.944335   0.944689       40.058973
# 3      LightGBMLarge_BAG_L2    0.944282   0.946680       42.661689
# 4       WeightedEnsemble_L3    0.943865   0.949720       61.983417
# 5            XGBoost_BAG_L2    0.943855   0.944776       41.619082
# 6   RandomForestEntr_BAG_L2    0.943129   0.947576       40.788802
# 7   RandomForestGini_BAG_L2    0.942920   0.947713       40.828299
# 8         LightGBMXT_BAG_L2    0.942862   0.945452       58.892951
# 9     NeuralNetMXNet_BAG_L2    0.942005   0.942457       52.116419
# 10    ExtraTreesEntr_BAG_L2    0.941216   0.947140       41.070944
# 11    ExtraTreesGini_BAG_L2    0.941120   0.947308       41.100532
# 12      WeightedEnsemble_L2    0.670929   0.672252       10.483768
# 13          LightGBM_BAG_L1    0.670610   0.671102        1.364376
# 14          CatBoost_BAG_L1    0.664245   0.665181        0.190291
# 15     LightGBMLarge_BAG_L1    0.660096   0.662764        1.300611
# 16   NeuralNetFastAI_BAG_L1    0.658085   0.656675        7.813278
# 17           XGBoost_BAG_L1    0.657615   0.656357        1.186747
# 18        LightGBMXT_BAG_L1    0.651744   0.652824        3.115709
# 19    NeuralNetMXNet_BAG_L1    0.632806   0.630440       11.522386
# 20    KNeighborsUnif_BAG_L1    0.499083   0.494399        2.224422
# 21  RandomForestEntr_BAG_L1    0.383758   0.383472        2.156273
# 22  RandomForestGini_BAG_L1    0.380552   0.380056        1.629105
# 23    ExtraTreesEntr_BAG_L1    0.348242   0.347511        2.490486
# 24    ExtraTreesGini_BAG_L1    0.346736   0.346693        2.626685
# 25    KNeighborsDist_BAG_L1    0.254296   0.249756        2.230434
#
#     pred_time_val     fit_time  pred_time_test_marginal  \
# 0       25.167060  2863.852661                 7.905569
# 1       24.348277  1994.704804                 2.662714
# 2       24.021507  2072.585986                 0.208168
# 3       24.380373  2018.434395                 2.810885
# 4       37.210031  3214.693246                 0.008039
# 5       24.199243  1993.609966                 1.768278
# 6       25.834585  1989.950431                 0.937998
# 7       25.892469  1979.724148                 0.977494
# 8       26.662084  2088.459737                19.042147
# 9       27.795319  3042.835804                12.265615
# 10      26.215806  1966.597646                 1.220139
# 11      26.276035  1965.778201                 1.249727
# 12       1.540642   909.833842                 0.005502
# 13       0.234921    15.396821                 1.364376
# 14       0.076926   103.492475                 0.190291
# 15       0.228082    20.823881                 1.300611
# 16       1.059927   850.682163                 7.813278
# 17       0.198474    11.363792                 1.186747
# 18       0.460032    29.029012                 3.115709
# 19       3.877782   877.250759                11.522386
# 20       2.724805     0.194548                 2.224422
# 21       2.755520    22.310024                 2.156273
# 22       2.675128    14.287951                 1.629105
# 23       3.087351     8.128519                 2.490486
# 24       3.122340     7.322661                 2.626685
# 25       3.423805     0.164611                 2.230434
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 1.241967         903.405443            2       True
# 1                 0.423184          34.257587            2       True
# 2                 0.096414         112.138768            2       True
# 3                 0.455280          57.987177            2       True
# 4                 0.017724          19.351125            3       True
# 5                 0.274150          33.162748            2       True
# 6                 1.909492          29.503213            2       True
# 7                 1.967376          19.276930            2       True
# 8                 2.736991         128.012519            2       True
# 9                 3.870226        1082.388586            2       True
# 10                2.290713           6.150428            2       True
# 11                2.350942           5.330984            2       True
# 12                0.017712          22.930977            2       True
# 13                0.234921          15.396821            1       True
# 14                0.076926         103.492475            1       True
# 15                0.228082          20.823881            1       True
# 16                1.059927         850.682163            1       True
# 17                0.198474          11.363792            1       True
# 18                0.460032          29.029012            1       True
# 19                3.877782         877.250759            1       True
# 20                2.724805           0.194548            1       True
# 21                2.755520          22.310024            1       True
# 22                2.675128          14.287951            1       True
# 23                3.087351           8.128519            1       True
# 24                3.122340           7.322661            1       True
# 25                3.423805           0.164611            1       True
#
#     fit_order
# 0          22
# 1          16
# 2          19
# 3          25
# 4          26
# 5          23
# 6          18
# 7          17
# 8          15
# 9          24
# 10         21
# 11         20
# 12         14
# 13          4
# 14          7
# 15         13
# 16         10
# 17         11
# 18          3
# 19         12
# 20          1
# 21          6
# 22          5
# 23          9
# 24          8
# 25          2

# %%
pred_probs = predictor.predict_proba(test_data_nolab)
pred_probs.head(5)
# Out:
#                0         1
# 85860   0.562518  0.437483
# 50844   0.000357  0.999643
# 138749  0.047992  0.952008
# 107305  0.999867  0.000132
# 154932  0.014611  0.985389

# %%
from sklearn.metrics import accuracy_score
y_predi = predictor.predict(test_data)
score = accuracy_score(y_test,y_predi)
print(score)
# Out:
# 0.8397703895414427

# %%
# Accuracy with NeuralNetFastAI_BAG_L2
from sklearn.metrics import accuracy_score
y_predi = predictor.predict(test_data, model='NeuralNetFastAI_BAG_L2')
score = accuracy_score(y_test,y_predi)
print(score)
# Out:
# 0.8406330877961378

# %%
# Accuracy with LightGBM_BAG_L2
from sklearn.metrics import accuracy_score
y_predi = predictor.predict(test_data, model='LightGBM_BAG_L2')
score = accuracy_score(y_test,y_predi)
print(score)
# Out:
# 0.8401353772645829
