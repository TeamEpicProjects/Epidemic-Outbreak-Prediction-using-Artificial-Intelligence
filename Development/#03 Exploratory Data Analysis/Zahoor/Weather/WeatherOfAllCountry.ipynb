# %% [markdown]
# # Analyse the pattern of weather of all countries

# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import re
import datetime

import matplotlib.style as style
# %matplotlib inline
style.use('ggplot')

import warnings
warnings.simplefilter("ignore")

pd.pandas.set_option('display.max_columns',None)

# %%
weather = pd.read_csv('weatherdataset.csv')
weather.head()
# Out:
#     date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2016-03-19        22        13           0.0     11.6        5
# 1  2016-03-20        22        16           0.0     11.6        5
# 2  2016-03-21        24        17           0.0     10.3        5
# 3  2016-03-22        28        19           0.0     11.6        6
# 4  2016-03-23        30        17           0.0     11.6        6
#
#    moon_illumination  moonrise   moonset   sunrise    sunset  DewPointC  \
# 0                 73  05:01 PM  03:19 AM  06:57 AM  07:07 PM          9
# 1                 80  05:38 PM  04:15 AM  06:58 AM  07:05 PM         10
# 2                 87  06:11 PM  05:10 AM  06:59 AM  07:04 PM         14
# 3                 94  06:44 PM  06:05 AM  07:00 AM  07:02 PM         16
# 4                100  07:16 PM  06:59 AM  07:01 AM  07:01 PM         14
#
#    FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 0          17          18          17            36          10        58
# 1          19          19          19            29          22        58
# 2          20          21          20            20          58        69
# 3          24          24          23            11           2        65
# 4          24          24          23            19           2        60
#
#    precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 0       0.0      1023     22          10            125             27
# 1       0.1      1022     22          10             95             21
# 2       3.4      1017     24          10             95             15
# 3       0.0      1016     28          10            117              8
# 4       0.0      1015     30          10            139             14
#
#     location
# 0  Argentina
# 1  Argentina
# 2  Argentina
# 3  Argentina
# 4  Argentina

# %%
# Convert our report_date columns to datetime datatype
weather['date_time'] = pd.to_datetime(weather['date_time'], format="%Y-%m-%d")

# create new year and month column from datetime
weather['year'] = pd.DatetimeIndex(weather['date_time']).year
weather['month'] = pd.DatetimeIndex(weather['date_time']).month

# %%
weather.shape
# Out:
# (7420, 27)

# %% [markdown]
# # 1 Argentina

# %%
argentina_weather = weather[weather['location'] == 'Argentina']
argentina_weather.head()
# Out:
#    date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0 2016-03-19        22        13           0.0     11.6        5
# 1 2016-03-20        22        16           0.0     11.6        5
# 2 2016-03-21        24        17           0.0     10.3        5
# 3 2016-03-22        28        19           0.0     11.6        6
# 4 2016-03-23        30        17           0.0     11.6        6
#
#    moon_illumination  moonrise   moonset   sunrise    sunset  DewPointC  \
# 0                 73  05:01 PM  03:19 AM  06:57 AM  07:07 PM          9
# 1                 80  05:38 PM  04:15 AM  06:58 AM  07:05 PM         10
# 2                 87  06:11 PM  05:10 AM  06:59 AM  07:04 PM         14
# 3                 94  06:44 PM  06:05 AM  07:00 AM  07:02 PM         16
# 4                100  07:16 PM  06:59 AM  07:01 AM  07:01 PM         14
#
#    FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 0          17          18          17            36          10        58
# 1          19          19          19            29          22        58
# 2          20          21          20            20          58        69
# 3          24          24          23            11           2        65
# 4          24          24          23            19           2        60
#
#    precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 0       0.0      1023     22          10            125             27
# 1       0.1      1022     22          10             95             21
# 2       3.4      1017     24          10             95             15
# 3       0.0      1016     28          10            117              8
# 4       0.0      1015     30          10            139             14
#
#     location  year  month
# 0  Argentina  2016      3
# 1  Argentina  2016      3
# 2  Argentina  2016      3
# 3  Argentina  2016      3
# 4  Argentina  2016      3

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=argentina_weather,palette=['green','black'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=argentina_weather,palette=['green','black'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=argentina_weather,palette=['green','black'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# # 2 United states

# %%
us_weather = weather[weather['location'] == 'United_States']
us_weather.head()
# Out:
#       date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 6297 2016-02-16        19        10           0.0     11.1        5
# 6298 2016-02-17        18        12           0.0     11.1        4
# 6299 2016-02-18        21        10           0.0     11.1        5
# 6300 2016-02-19        22        14           0.0     11.2        4
# 6301 2016-02-20        21        15           0.0      5.6        4
#
#       moon_illumination  moonrise   moonset   sunrise    sunset  DewPointC  \
# 6297                 57  01:43 PM  02:39 AM  07:46 AM  06:56 PM          9
# 6298                 64  02:35 PM  03:37 AM  07:45 AM  06:57 PM          9
# 6299                 72  03:30 PM  04:31 AM  07:45 AM  06:58 PM          8
# 6300                 79  04:26 PM  05:22 AM  07:44 AM  06:59 PM         13
# 6301                 87  05:22 PM  06:07 AM  07:43 AM  06:59 PM         16
#
#       FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 6297          14          14          14            17           6        72
# 6298          13          14          13            16           3        73
# 6299          14          15          14            20           0        63
# 6300          17          18          17            22           2        79
# 6301          18          18          18            18          58        86
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 6297       0.0      1015     19          10            199             10
# 6298       0.0      1022     18          10            105             10
# 6299       0.0      1026     21          10            127             11
# 6300       0.0      1024     22           9            155             13
# 6301       0.2      1021     21           8            157             11
#
#            location  year  month
# 6297  United_States  2016      2
# 6298  United_States  2016      2
# 6299  United_States  2016      2
# 6300  United_States  2016      2
# 6301  United_States  2016      2

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=us_weather,palette=['green','black'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=us_weather,palette=['green','black'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=us_weather,palette=['green','black'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# # 3 Brazil

# %%
brazil_weather = weather[weather['location'] == 'Brazil']
brazil_weather.head()
# Out:
#      date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 458 2016-02-13        26        19           0.0     11.6        5
# 459 2016-02-14        26        18           0.0     11.6        5
# 460 2016-02-15        26        18           0.0     11.6        5
# 461 2016-02-16        27        18           0.0     11.6        5
# 462 2016-02-17        29        18           0.0     11.6        5
#
#      moon_illumination  moonrise     moonset   sunrise    sunset  DewPointC  \
# 458                 34  10:52 AM    10:54 PM  06:07 AM  06:45 PM         20
# 459                 42  11:50 AM    11:44 PM  06:07 AM  06:44 PM         20
# 460                 49  12:48 PM  No moonset  06:07 AM  06:44 PM         19
# 461                 57  01:46 PM    12:36 AM  06:08 AM  06:43 PM         18
# 462                 64  02:41 PM    01:29 AM  06:08 AM  06:43 PM         19
#
#      FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 458          23          23          22             8          39        88
# 459          23          23          22            10          30        87
# 460          23          23          22            15          32        85
# 461          23          23          22            11          18        81
# 462          24          24          23            12          15        79
#
#      precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 458      20.9      1012     26           9            292              5
# 459      22.2      1012     26           8            311              7
# 460       8.4      1013     26           8            191             10
# 461       2.4      1014     27          10             45              7
# 462       0.8      1013     29           9             63              8
#
#     location  year  month
# 458   Brazil  2016      2
# 459   Brazil  2016      2
# 460   Brazil  2016      2
# 461   Brazil  2016      2
# 462   Brazil  2016      2

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=brazil_weather,palette=['green'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=brazil_weather,palette=['green'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=brazil_weather,palette=['green'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# # 4 Colombia

# %%
col_weather = weather[weather['location'] == 'Colombia']
col_weather.head()
# Out:
#      date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 781 2016-01-09        23        10           0.0     11.6        4
# 782 2016-01-10        24         9           0.0     11.6        4
# 783 2016-01-11        23        10           0.0     10.2        4
# 784 2016-01-12        25        11           0.0     11.6        4
# 785 2016-01-13        22        11           0.0     11.6        4
#
#      moon_illumination  moonrise   moonset   sunrise    sunset  DewPointC  \
# 781                  0  05:35 AM  05:48 PM  06:07 AM  06:00 PM         12
# 782                  0  06:29 AM  06:44 PM  06:07 AM  06:00 PM         11
# 783                  8  07:23 AM  07:40 PM  06:08 AM  06:00 PM         12
# 784                 15  08:15 AM  08:34 PM  06:08 AM  06:01 PM         12
# 785                 22  09:07 AM  09:29 PM  06:08 AM  06:01 PM         11
#
#      FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 781          16          16          16             3          26        84
# 782          15          16          15             4          35        81
# 783          15          16          15             4          33        83
# 784          16          17          16             3          35        81
# 785          15          15          15             4          26        81
#
#      precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 781       5.6      1012     23           8            128              2
# 782       2.9      1013     24           8            140              2
# 783       1.0      1014     23           7            133              2
# 784       1.2      1014     25           8            150              2
# 785       1.2      1014     22           9            160              2
#
#      location  year  month
# 781  Colombia  2016      1
# 782  Colombia  2016      1
# 783  Colombia  2016      1
# 784  Colombia  2016      1
# 785  Colombia  2016      1

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=col_weather,palette=['green'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=col_weather,palette=['green'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=col_weather,palette=['green'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# # 5 Dominican Republic

# %%
dom_weather = weather[weather['location'] == 'Dominican_Republic']
dom_weather.head()
# Out:
#       date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 1139 2016-01-09        32        22           0.0     11.1        7
# 1140 2016-01-10        34        22           0.0     11.1        7
# 1141 2016-01-11        33        22           0.0     11.1        7
# 1142 2016-01-12        33        20           0.0     11.1        7
# 1143 2016-01-13        31        21           0.0     11.1        7
#
#       moon_illumination  moonrise   moonset   sunrise    sunset  DewPointC  \
# 1139                  0  06:37 AM  06:11 PM  07:14 AM  06:19 PM         20
# 1140                  0  07:30 AM  07:09 PM  07:14 AM  06:20 PM         18
# 1141                  8  08:21 AM  08:08 PM  07:14 AM  06:20 PM         19
# 1142                 15  09:10 AM  09:07 PM  07:15 AM  06:21 PM         19
# 1143                 22  09:58 AM  10:05 PM  07:15 AM  06:22 PM         19
#
#       FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 1139          28          28          26            11           7        71
# 1140          28          28          26            11           0        65
# 1141          27          27          25            14          14        70
# 1142          26          26          25            15          19        73
# 1143          26          26          24            13          24        75
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 1139       0.1      1014     32          10             42              8
# 1140       0.0      1015     34          10             38              9
# 1141       0.0      1017     33          10             30             10
# 1142       0.0      1016     33          10             87             10
# 1143       0.6      1016     31          10             44              9
#
#                 location  year  month
# 1139  Dominican_Republic  2016      1
# 1140  Dominican_Republic  2016      1
# 1141  Dominican_Republic  2016      1
# 1142  Dominican_Republic  2016      1
# 1143  Dominican_Republic  2016      1

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=dom_weather,palette=['green','black'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=dom_weather,palette=['green','black'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=dom_weather,palette=['green','black'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# # 6 Ecuador

# %%
ecd_weather = weather[weather['location'] == 'Ecuador']
ecd_weather.head()
# Out:
#       date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 1588 2016-03-30        17        11           0.0      8.8        3
# 1589 2016-03-31        15         9           0.0      6.0        3
# 1590 2016-04-01        15        10           0.0      6.0        3
# 1591 2016-04-02        16         8           0.0      7.4        3
# 1592 2016-04-03        16         8           0.0      8.8        3
#
#       moon_illumination     moonrise   moonset   sunrise    sunset  DewPointC  \
# 1588                 47  No moonrise  11:37 AM  06:15 AM  06:21 PM         12
# 1589                 43     12:03 AM  12:28 PM  06:15 AM  06:21 PM         11
# 1590                 26     12:54 AM  01:20 PM  06:14 AM  06:21 PM         11
# 1591                 19     01:47 AM  02:13 PM  06:14 AM  06:20 PM         10
# 1592                 11     02:40 AM  03:06 PM  06:14 AM  06:20 PM         10
#
#       FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 1588          13          13          13             6          52        93
# 1589          12          12          12             6          72        93
# 1590          11          12          11             6          97        94
# 1591          11          11          11             7          72        92
# 1592          11          11          11             8          61        91
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 1588      18.1      1015     17           7            284              4
# 1589      15.7      1016     15           7            166              4
# 1590      47.8      1015     15           6            242              5
# 1591      17.7      1015     16           7            180              5
# 1592      11.7      1015     16           7            188              5
#
#      location  year  month
# 1588  Ecuador  2016      3
# 1589  Ecuador  2016      3
# 1590  Ecuador  2016      4
# 1591  Ecuador  2016      4
# 1592  Ecuador  2016      4

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=ecd_weather,palette=['green','black'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=ecd_weather,palette=['green','black'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=ecd_weather,palette=['green','black'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# # 7 El Salvador

# %%
sal_weather = weather[weather['location'] == 'El_Salvador']
sal_weather.head()
# Out:
#       date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 2219 2015-11-28        35        21           0.0      8.7        7
# 2220 2015-11-29        33        22           0.0      8.7        7
# 2221 2015-11-30        34        21           0.0      8.7        7
# 2222 2015-12-01        34        19           0.0      8.7        7
# 2223 2015-12-02        36        20           0.0      8.7        7
#
#       moon_illumination  moonrise   moonset   sunrise    sunset  DewPointC  \
# 2219                 78  08:23 PM  08:32 AM  06:03 AM  05:27 PM         19
# 2220                 71  09:18 PM  09:24 AM  06:03 AM  05:27 PM         18
# 2221                 63  10:09 PM  10:12 AM  06:04 AM  05:27 PM         17
# 2222                 61  10:59 PM  10:57 AM  06:04 AM  05:27 PM         17
# 2223                 54  11:48 PM  11:39 AM  06:05 AM  05:28 PM         18
#
#       FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 2219          29          29          27             9           8        64
# 2220          28          28          27            10           3        62
# 2221          27          27          26            10           3        60
# 2222          27          27          26             8          11        62
# 2223          28          28          26             7          14        64
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 2219       0.0      1012     35          10            226              6
# 2220       0.0      1011     33          10             47              8
# 2221       0.0      1010     34          10            222              7
# 2222       0.0      1010     34          10            292              5
# 2223       0.0      1011     36          10            305              4
#
#          location  year  month
# 2219  El_Salvador  2015     11
# 2220  El_Salvador  2015     11
# 2221  El_Salvador  2015     11
# 2222  El_Salvador  2015     12
# 2223  El_Salvador  2015     12

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=sal_weather,palette=['green','black','yellow'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=sal_weather,palette=['green','black','yellow'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=sal_weather,palette=['green','black','yellow'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# # 8 Guatemala

# %%
gat_weather = weather[weather['location'] == 'Guatemala']
gat_weather.head()
# Out:
#       date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 2975 2015-12-09        23        14           0.0      8.7        5
# 2976 2015-12-10        24        14           0.0      8.7        5
# 2977 2015-12-11        24        14           0.0      8.7        5
# 2978 2015-12-12        25        14           0.0      8.7        6
# 2979 2015-12-13        24        14           0.0      8.7        6
#
#       moon_illumination  moonrise   moonset   sunrise    sunset  DewPointC  \
# 2975                  3  04:37 AM  04:26 PM  06:16 AM  05:33 PM         14
# 2976                  0  05:29 AM  05:14 PM  06:16 AM  05:34 PM         14
# 2977                  0  06:21 AM  06:05 PM  06:17 AM  05:34 PM         14
# 2978                  4  07:14 AM  06:58 PM  06:17 AM  05:34 PM         14
# 2979                 12  08:06 AM  07:53 PM  06:18 AM  05:35 PM         14
#
#       FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 2975          17          18          17            21          29        80
# 2976          18          19          18            16          29        79
# 2977          18          18          18            18          17        78
# 2978          18          19          18            13          17        77
# 2979          18          19          18            10          21        80
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 2975       0.0      1014     23          10             11             13
# 2976       0.3      1014     24          10            116              9
# 2977       0.1      1013     24          10             15             11
# 2978       0.0      1013     25          10             39              7
# 2979       0.3      1011     24          10            195              7
#
#        location  year  month
# 2975  Guatemala  2015     12
# 2976  Guatemala  2015     12
# 2977  Guatemala  2015     12
# 2978  Guatemala  2015     12
# 2979  Guatemala  2015     12

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=gat_weather,palette=['green','black','yellow'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=gat_weather,palette=['green','black','yellow'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=gat_weather,palette=['green','black','yellow'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# # 9 Mexico

# %%
mexico_weather = weather[weather['location'] == 'Mexico']
mexico_weather.head()
# Out:
#       date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 3702 2015-11-28        25        12           0.0     11.1        5
# 3703 2015-11-29        28        10           0.0     11.0        5
# 3704 2015-11-30        29        10           0.0     11.0        6
# 3705 2015-12-01        30        11           0.0     11.0        6
# 3706 2015-12-02        28        11           0.0     11.0        5
#
#       moon_illumination     moonrise   moonset   sunrise    sunset  DewPointC  \
# 3702                 78     09:56 PM  10:21 AM  07:52 AM  06:57 PM         11
# 3703                 71     10:51 PM  11:13 AM  07:53 AM  06:57 PM         10
# 3704                 63     11:45 PM  12:00 PM  07:54 AM  06:57 PM          9
# 3705                 61  No moonrise  12:43 PM  07:54 AM  06:57 PM          7
# 3706                 54     12:36 AM  01:24 PM  07:55 AM  06:57 PM          9
#
#       FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 3702          17          17          17             8          16        71
# 3703          18          18          18             8           9        63
# 3704          19          19          19             5           5        59
# 3705          20          20          20             5           1        48
# 3706          18          18          18             5           5        59
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 3702       0.0      1017     25          10            210              5
# 3703       0.0      1017     28          10             57              5
# 3704       0.0      1014     29          10            194              3
# 3705       0.0      1014     30          10            216              3
# 3706       0.0      1014     28          10            186              4
#
#      location  year  month
# 3702   Mexico  2015     11
# 3703   Mexico  2015     11
# 3704   Mexico  2015     11
# 3705   Mexico  2015     12
# 3706   Mexico  2015     12

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=mexico_weather,palette=['green','black','yellow','blue'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=mexico_weather,palette=['green','black','yellow','blue'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=mexico_weather,palette=['green','black','yellow','blue'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# # 10 Nicaragua

# %%
nig_weather = weather[weather['location'] == 'Nicaragua']
nig_weather.head()
# Out:
#       date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 4648 2016-02-09        33        23           0.0      8.7        7
# 4649 2016-02-10        32        22           0.0      8.7        7
# 4650 2016-02-11        33        22           0.0      8.7        7
# 4651 2016-02-12        34        23           0.0      8.7        7
# 4652 2016-02-13        35        23           0.0      8.7        8
#
#       moon_illumination  moonrise   moonset   sunrise    sunset  DewPointC  \
# 4648                  4  06:53 AM  07:05 PM  06:09 AM  05:50 PM         16
# 4649                 12  07:44 AM  08:03 PM  06:08 AM  05:50 PM         14
# 4650                 19  08:33 AM  09:01 PM  06:08 AM  05:51 PM         15
# 4651                 27  09:23 AM  09:59 PM  06:08 AM  05:51 PM         17
# 4652                 34  10:12 AM  10:56 PM  06:07 AM  05:51 PM         18
#
#       FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 4648          28          28          27            35          21        52
# 4649          27          27          26            39          18        49
# 4650          28          28          26            38          18        52
# 4651          29          29          28            39          15        54
# 4652          30          30          28            42          13        56
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 4648       0.0      1014     33          10             65             26
# 4649       0.0      1015     32          10             60             29
# 4650       0.0      1014     33          10             66             29
# 4651       0.0      1013     34          10             65             29
# 4652       0.0      1012     35          10             60             31
#
#        location  year  month
# 4648  Nicaragua  2016      2
# 4649  Nicaragua  2016      2
# 4650  Nicaragua  2016      2
# 4651  Nicaragua  2016      2
# 4652  Nicaragua  2016      2

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=nig_weather,palette=['green'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=nig_weather,palette=['green'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=nig_weather,palette=['green'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# # 11 Panama

# %%
pama_weather = weather[weather['location'] == 'Panama']
pama_weather.head()
# Out:
#       date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 4873 2016-01-06        30        25           0.0     11.6        6
# 4874 2016-01-07        31        25           0.0      8.7        6
# 4875 2016-01-08        31        25           0.0      8.7        6
# 4876 2016-01-09        31        25           0.0     10.2        6
# 4877 2016-01-10        31        24           0.0     11.6        6
#
#       moon_illumination  moonrise   moonset   sunrise    sunset  DewPointC  \
# 4873                 14  03:26 AM  03:28 PM  06:35 AM  06:12 PM         24
# 4874                  7  04:17 AM  04:17 PM  06:35 AM  06:13 PM         23
# 4875                  0  05:10 AM  05:10 PM  06:36 AM  06:14 PM         23
# 4876                  0  06:03 AM  06:05 PM  06:36 AM  06:14 PM         22
# 4877                  0  06:57 AM  07:01 PM  06:36 AM  06:15 PM         22
#
#       FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 4873          30          30          27            15          49        82
# 4874          30          30          27            13          49        79
# 4875          30          30          27            12          54        79
# 4876          30          30          27            13          49        77
# 4877          29          29          26            14          31        78
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 4873       7.2      1012     30           9            343             10
# 4874       0.6      1011     31          10            301              8
# 4875       0.2      1011     31          10            298              8
# 4876       0.2      1011     31          10            253              8
# 4877       0.2      1012     31          10            255              9
#
#      location  year  month
# 4873   Panama  2016      1
# 4874   Panama  2016      1
# 4875   Panama  2016      1
# 4876   Panama  2016      1
# 4877   Panama  2016      1

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=pama_weather,palette=['black','yellow'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=pama_weather,palette=['black','yellow'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=pama_weather,palette=['black','yellow'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# # 12 Puerto Rico

# %%
rico_weather = weather[weather['location'] == 'Puerto_Rico']
rico_weather.head()
# Out:
#       date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 5595 2016-01-27        28        21           0.0      9.5        5
# 5596 2016-01-28        31        21           0.0     10.8        6
# 5597 2016-01-29        36        22           0.0     13.2        7
# 5598 2016-01-30        29        22           0.0     13.2        6
# 5599 2016-01-31        25        21           0.0      9.5        5
#
#       moon_illumination  moonrise   moonset   sunrise    sunset  DewPointC  \
# 5595                 76  08:54 PM  08:15 AM  05:10 AM  06:35 PM         21
# 5596                 69  09:29 PM  09:06 AM  05:11 AM  06:35 PM         22
# 5597                 61  10:03 PM  09:57 AM  05:11 AM  06:35 PM         22
# 5598                 54  10:38 PM  10:47 AM  05:12 AM  06:34 PM         23
# 5599                 50  11:16 PM  11:38 AM  05:13 AM  06:34 PM         22
#
#       FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 5595          26          26          24            11          83        88
# 5596          29          29          26            14          50        83
# 5597          32          32          28            13          27        74
# 5598          29          29          25            12          38        88
# 5599          25          25          23            10          83        97
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 5595       3.4      1009     28           6            148              7
# 5596       4.2      1010     31           9             61              9
# 5597       1.1      1010     36          10             48              8
# 5598      13.9      1010     29           8             95              7
# 5599      17.6      1011     25           8             80              6
#
#          location  year  month
# 5595  Puerto_Rico  2016      1
# 5596  Puerto_Rico  2016      1
# 5597  Puerto_Rico  2016      1
# 5598  Puerto_Rico  2016      1
# 5599  Puerto_Rico  2016      1

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=rico_weather,palette=['black','yellow'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=rico_weather,palette=['black','yellow'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=rico_weather,palette=['black','yellow'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')

# %% [markdown]
# # 13 U.S. Virgin Islands

# %%
virgin_weather = weather[weather['location'] == 'Virgin_Islands']
virgin_weather.head()
# Out:
#       date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 6872 2016-02-24        27        26           0.0     11.6        7
# 6873 2016-02-25        27        26           0.0     11.6        6
# 6874 2016-02-26        27        26           0.0     11.6        6
# 6875 2016-02-27        27        25           0.0     11.6        7
# 6876 2016-02-28        27        25           0.0     11.6        6
#
#       moon_illumination  moonrise   moonset   sunrise    sunset  DewPointC  \
# 6872                 83  08:05 PM  07:47 AM  06:41 AM  06:22 PM         22
# 6873                 75  08:53 PM  08:24 AM  06:40 AM  06:23 PM         22
# 6874                 68  09:41 PM  09:01 AM  06:40 AM  06:23 PM         21
# 6875                 60  10:29 PM  09:40 AM  06:39 AM  06:23 PM         21
# 6876                 53  11:18 PM  10:19 AM  06:38 AM  06:24 PM         21
#
#       FeelsLikeC  HeatIndexC  WindChillC  WindGustKmph  cloudcover  humidity  \
# 6872          29          29          27            36          29        76
# 6873          29          29          26            32          36        76
# 6874          28          28          26            29          28        74
# 6875          28          28          26            22          33        73
# 6876          28          28          26            19          14        73
#
#       precipMM  pressure  tempC  visibility  winddirDegree  windspeedKmph  \
# 6872       0.4      1017     27          10            100             26
# 6873       1.4      1017     27          10             92             23
# 6874       1.5      1017     27          10             91             21
# 6875       0.1      1016     27          10             95             16
# 6876       8.6      1016     27           9            105             14
#
#             location  year  month
# 6872  Virgin_Islands  2016      2
# 6873  Virgin_Islands  2016      2
# 6874  Virgin_Islands  2016      2
# 6875  Virgin_Islands  2016      2
# 6876  Virgin_Islands  2016      2

# %%
fig, axes = plt.subplots(3, figsize=(15, 18))
sns.lineplot(ax=axes[0], x='month', y='maxtempC', hue='year',data=virgin_weather,palette=['black','yellow'])
axes[0].set_title('Max temperature')

sns.lineplot(ax=axes[1], x='month', y='precipMM', hue='year',data=virgin_weather,palette=['black','yellow'])
axes[1].set_title('Precipitation')

sns.lineplot(ax=axes[2], x='month', y='humidity', hue='year',data=virgin_weather,palette=['black','yellow'])
axes[2].set_title('Humidity')
# Out:
# Text(0.5, 1.0, 'Humidity')
