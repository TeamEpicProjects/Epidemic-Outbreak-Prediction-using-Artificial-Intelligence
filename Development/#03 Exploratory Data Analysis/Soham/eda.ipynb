# %%
import pandas as pd
import numpy as np
import re

# %%
df_weather = pd.read_csv('./datasets/weatherdataset.csv')
df_weather.head(5)
# Out:
#     date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2016-03-19        22        13           0.0     11.6        5
# 1  2016-03-20        22        16           0.0     11.6        5
# 2  2016-03-21        24        17           0.0     10.3        5
# 3  2016-03-22        28        19           0.0     11.6        6
# 4  2016-03-23        30        17           0.0     11.6        6
#
#    moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 0                 73  05:01 PM  03:19 AM  06:57 AM  ...           36
# 1                 80  05:38 PM  04:15 AM  06:58 AM  ...           29
# 2                 87  06:11 PM  05:10 AM  06:59 AM  ...           20
# 3                 94  06:44 PM  06:05 AM  07:00 AM  ...           11
# 4                100  07:16 PM  06:59 AM  07:01 AM  ...           19
#
#    cloudcover  humidity  precipMM  pressure  tempC  visibility  winddirDegree  \
# ...

# %%
df_population = pd.read_csv('./datasets/population_density.csv')
df_population.head(5)
# Out:
#                  location  density_per_km
# 0  Argentina-Buenos_Aires    12625.800781
# 1          Argentina-CABA    12625.800781
# 2       Argentina-Cordoba     2404.108887
# 3    Argentina-Entre_Rios       72.495293
# 4      Argentina-Santa_Fe      208.092285

# %%
df_zikavirus= pd.read_csv('./datasets/zikavirus.csv')
df_zikavirus.head(5)
# Out:
#   report_date                location location_type  \
# 0  2017-01-12  Argentina-Buenos_Aires      province
# 1  2017-01-12          Argentina-CABA      province
# 2  2017-01-12       Argentina-Cordoba      province
# 3  2017-01-12    Argentina-Entre_Rios      province
# 4  2017-01-12      Argentina-Santa_Fe      province
#
#                             data_field cases
# 0  cumulative_confirmed_imported_cases   0.0
# 1  cumulative_confirmed_imported_cases   1.0
# 2  cumulative_confirmed_imported_cases   2.0
# 3  cumulative_confirmed_imported_cases   0.0
# 4  cumulative_confirmed_imported_cases   2.0

# %%
df = pd.concat(map(pd.read_csv, ['./datasets/zikavirus.csv', './datasets/weatherdataset.csv', './datasets/population_density.csv']), axis=1, ignore_index=False)
df.head(5)
# Out:
#   report_date                location location_type  \
# 0  2017-01-12  Argentina-Buenos_Aires      province
# 1  2017-01-12          Argentina-CABA      province
# 2  2017-01-12       Argentina-Cordoba      province
# 3  2017-01-12    Argentina-Entre_Rios      province
# 4  2017-01-12      Argentina-Santa_Fe      province
#
#                             data_field cases   date_time  maxtempC  mintempC  \
# 0  cumulative_confirmed_imported_cases   0.0  2016-03-19      22.0      13.0
# 1  cumulative_confirmed_imported_cases   1.0  2016-03-20      22.0      16.0
# 2  cumulative_confirmed_imported_cases   2.0  2016-03-21      24.0      17.0
# 3  cumulative_confirmed_imported_cases   0.0  2016-03-22      28.0      19.0
# 4  cumulative_confirmed_imported_cases   2.0  2016-03-23      30.0      17.0
#
#    totalSnow_cm  sunHour  ...  humidity  precipMM pressure tempC visibility  \
# 0           0.0     11.6  ...      58.0       0.0   1023.0  22.0       10.0
# ...

# %%
df.shape
# Out:
# (242450, 32)

# %%
df_mod = df[df.location.str.contains('argentina')]
df_mod.head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8084/3599736016.py in <module>
# ----> 1 df_mod = df[df.location.str.contains('argentina')]
#       2 df_mod.head(5)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'str'
