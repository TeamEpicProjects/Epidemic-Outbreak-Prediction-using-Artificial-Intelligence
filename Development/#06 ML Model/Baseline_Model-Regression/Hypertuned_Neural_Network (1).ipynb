# %%
# !pip install -q -U keras-tuner
# Out:
#      |████████████████████████████████| 97 kB 3.0 MB/s

# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch

# %%
df=pd.read_csv('regression_dataset.csv')
df.head()
# Out:
#    cases   latitude  longitude  maxtempC  ...  year  month  density_per_km  precipMM
# 0      2 -34.603684 -58.381559        24  ...  2016      3        0.505636       0.0
# 1      0 -34.603684 -58.381559        24  ...  2016      3        0.505636       0.0
# 2      1 -34.603684 -58.381559        24  ...  2016      3        0.505636       0.0
# 3      0 -34.603684 -58.381559        22  ...  2016      4        0.505636       0.0
# 4      1 -34.603684 -58.381559        22  ...  2016      4        0.505636       0.0
#
# [5 rows x 25 columns]

# %%
X = df[['maxtempC', 'mintempC', 'windspeedKmph', 'year', 'month', 'density_per_km', 'precipMM', 'cloudcover',
       'humidity','DewPointC', 'latitude', 'longitude','FeelsLikeC', 'winddirDegree', 'sunHour']]
y = df['cases']

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 30)):
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=1024,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='mean_absolute_error',
        metrics=['mean_absolute_error'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mean_absolute_error',
    max_trials=3,
    executions_per_trial=2,
    directory='project',
    project_name='epidemic outbreak')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 30, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 1024, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 1024, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
tuner.search(X_train, y_train,
             epochs=100,
             validation_data=(X_test, y_test))
# Out:
# Trial 1 Complete [00h 54m 56s]
# val_mean_absolute_error: 57.776187896728516
#
# Best val_mean_absolute_error So Far: 57.776187896728516
# Total elapsed time: 00h 54m 56s
#
# Search: Running Trial #2
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |23                |18
# units_0           |544               |32
# units_1           |672               |64
# learning_rate     |0.01              |0.0001
# units_2           |320               |32
# units_3           |160               |32
# units_4           |608               |32
# units_5           |896               |32
# units_6           |896               |32
# units_7           |896               |32
# units_8           |896               |32
# units_9           |288               |32
# units_10          |864               |32
# units_11          |352               |32
# units_12          |640               |32
# units_13          |896               |32
# units_14          |448               |32
# units_15          |864               |32
# units_16          |608               |32
# units_17          |416               |32
#
# Epoch 1/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 6648.8325 - mean_absolute_error: 6648.8325 - val_loss: 58.6094 - val_mean_absolute_error: 58.6094
# Epoch 2/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3185 - mean_absolute_error: 61.3185 - val_loss: 58.6129 - val_mean_absolute_error: 58.6129
# Epoch 3/100
# 2577/2577 [==============================] - 32s 13ms/step - loss: 61.3180 - mean_absolute_error: 61.3180 - val_loss: 58.6117 - val_mean_absolute_error: 58.6117
# Epoch 4/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3178 - mean_absolute_error: 61.3178 - val_loss: 58.6083 - val_mean_absolute_error: 58.6083
# Epoch 5/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3171 - mean_absolute_error: 61.3171 - val_loss: 58.6089 - val_mean_absolute_error: 58.6089
# Epoch 6/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3173 - mean_absolute_error: 61.3173 - val_loss: 58.6099 - val_mean_absolute_error: 58.6099
# Epoch 7/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3171 - mean_absolute_error: 61.3171 - val_loss: 58.6098 - val_mean_absolute_error: 58.6098
# Epoch 8/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3175 - mean_absolute_error: 61.3175 - val_loss: 58.6098 - val_mean_absolute_error: 58.6098
# Epoch 9/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3175 - mean_absolute_error: 61.3175 - val_loss: 58.6088 - val_mean_absolute_error: 58.6088
# Epoch 10/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3172 - mean_absolute_error: 61.3172 - val_loss: 58.6099 - val_mean_absolute_error: 58.6099
# Epoch 11/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3177 - mean_absolute_error: 61.3177 - val_loss: 58.6089 - val_mean_absolute_error: 58.6089
# Epoch 12/100
# 2577/2577 [==============================] - 37s 14ms/step - loss: 61.3173 - mean_absolute_error: 61.3173 - val_loss: 58.6109 - val_mean_absolute_error: 58.6109
# Epoch 13/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3174 - mean_absolute_error: 61.3174 - val_loss: 58.6084 - val_mean_absolute_error: 58.6084
# Epoch 14/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6088 - val_mean_absolute_error: 58.6088
# Epoch 15/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3165 - mean_absolute_error: 61.3165 - val_loss: 58.6076 - val_mean_absolute_error: 58.6076
# Epoch 16/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6076 - val_mean_absolute_error: 58.6076
# Epoch 17/100
# 2577/2577 [==============================] - 31s 12ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6081 - val_mean_absolute_error: 58.6081
# Epoch 18/100
# 2577/2577 [==============================] - 32s 12ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6084 - val_mean_absolute_error: 58.6084
# Epoch 19/100
# 2577/2577 [==============================] - 32s 12ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6079 - val_mean_absolute_error: 58.6079
# Epoch 20/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6075 - val_mean_absolute_error: 58.6075
# Epoch 21/100
# 2577/2577 [==============================] - 32s 12ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6081 - val_mean_absolute_error: 58.6081
# Epoch 22/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3158 - mean_absolute_error: 61.3158 - val_loss: 58.6101 - val_mean_absolute_error: 58.6101
# Epoch 23/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3167 - mean_absolute_error: 61.3167 - val_loss: 58.6082 - val_mean_absolute_error: 58.6082
# Epoch 24/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6076 - val_mean_absolute_error: 58.6076
# Epoch 25/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3159 - mean_absolute_error: 61.3159 - val_loss: 58.6094 - val_mean_absolute_error: 58.6094
# Epoch 26/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3165 - mean_absolute_error: 61.3165 - val_loss: 58.6078 - val_mean_absolute_error: 58.6078
# Epoch 27/100
# 2577/2577 [==============================] - 32s 12ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6084 - val_mean_absolute_error: 58.6084
# Epoch 28/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6081 - val_mean_absolute_error: 58.6081
# Epoch 29/100
# 2577/2577 [==============================] - 32s 12ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6079 - val_mean_absolute_error: 58.6079
# Epoch 30/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6080 - val_mean_absolute_error: 58.6080
# Epoch 31/100
# 2577/2577 [==============================] - 32s 12ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6076 - val_mean_absolute_error: 58.6076
# Epoch 32/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3165 - mean_absolute_error: 61.3165 - val_loss: 58.6078 - val_mean_absolute_error: 58.6078
# Epoch 33/100
# 2577/2577 [==============================] - 32s 12ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6082 - val_mean_absolute_error: 58.6082
# Epoch 34/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 35/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6078 - val_mean_absolute_error: 58.6078
# Epoch 36/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6079 - val_mean_absolute_error: 58.6079
# Epoch 37/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3160 - mean_absolute_error: 61.3160 - val_loss: 58.6101 - val_mean_absolute_error: 58.6101
# Epoch 38/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3166 - mean_absolute_error: 61.3166 - val_loss: 58.6081 - val_mean_absolute_error: 58.6081
# Epoch 39/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6086 - val_mean_absolute_error: 58.6086
# Epoch 40/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6078 - val_mean_absolute_error: 58.6078
# Epoch 41/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6078 - val_mean_absolute_error: 58.6078
# Epoch 42/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6084 - val_mean_absolute_error: 58.6084
# Epoch 43/100
# 2577/2577 [==============================] - 32s 13ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6079 - val_mean_absolute_error: 58.6079
# Epoch 44/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6079 - val_mean_absolute_error: 58.6079
# Epoch 45/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6082 - val_mean_absolute_error: 58.6082
# Epoch 46/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 47/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 48/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 49/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6083 - val_mean_absolute_error: 58.6083
# Epoch 50/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6083 - val_mean_absolute_error: 58.6083
# Epoch 51/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6075 - val_mean_absolute_error: 58.6075
# Epoch 52/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6079 - val_mean_absolute_error: 58.6079
# Epoch 53/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6075 - val_mean_absolute_error: 58.6075
# Epoch 54/100
# 2577/2577 [==============================] - 37s 14ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 55/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6078 - val_mean_absolute_error: 58.6078
# Epoch 56/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6081 - val_mean_absolute_error: 58.6081
# Epoch 57/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6094 - val_mean_absolute_error: 58.6094
# Epoch 58/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 59/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6091 - val_mean_absolute_error: 58.6091
# Epoch 60/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6076 - val_mean_absolute_error: 58.6076
# Epoch 61/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3161 - mean_absolute_error: 61.3161 - val_loss: 58.6088 - val_mean_absolute_error: 58.6088
# Epoch 62/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6078 - val_mean_absolute_error: 58.6078
# Epoch 63/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 64/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 65/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6085 - val_mean_absolute_error: 58.6085
# Epoch 66/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6088 - val_mean_absolute_error: 58.6088
# Epoch 67/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6080 - val_mean_absolute_error: 58.6080
# Epoch 68/100
# 2577/2577 [==============================] - 35s 13ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6080 - val_mean_absolute_error: 58.6080
# Epoch 69/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6079 - val_mean_absolute_error: 58.6079
# Epoch 70/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6083 - val_mean_absolute_error: 58.6083
# Epoch 71/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3161 - mean_absolute_error: 61.3161 - val_loss: 58.6081 - val_mean_absolute_error: 58.6081
# Epoch 72/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6078 - val_mean_absolute_error: 58.6078
# Epoch 73/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6083 - val_mean_absolute_error: 58.6083
# Epoch 74/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6076 - val_mean_absolute_error: 58.6076
# Epoch 75/100
# 2577/2577 [==============================] - 37s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 76/100
# 2577/2577 [==============================] - 37s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6088 - val_mean_absolute_error: 58.6088
# Epoch 77/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6089 - val_mean_absolute_error: 58.6089
# Epoch 78/100
# 2577/2577 [==============================] - 37s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6087 - val_mean_absolute_error: 58.6087
# Epoch 79/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6096 - val_mean_absolute_error: 58.6096
# Epoch 80/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3161 - mean_absolute_error: 61.3161 - val_loss: 58.6082 - val_mean_absolute_error: 58.6082
# Epoch 81/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3161 - mean_absolute_error: 61.3161 - val_loss: 58.6078 - val_mean_absolute_error: 58.6078
# Epoch 82/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3161 - mean_absolute_error: 61.3161 - val_loss: 58.6099 - val_mean_absolute_error: 58.6099
# Epoch 83/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3166 - mean_absolute_error: 61.3166 - val_loss: 58.6083 - val_mean_absolute_error: 58.6083
# Epoch 84/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6081 - val_mean_absolute_error: 58.6081
# Epoch 85/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6086 - val_mean_absolute_error: 58.6086
# Epoch 86/100
# 2577/2577 [==============================] - 39s 15ms/step - loss: 61.3165 - mean_absolute_error: 61.3165 - val_loss: 58.6075 - val_mean_absolute_error: 58.6075
# Epoch 87/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6078 - val_mean_absolute_error: 58.6078
# Epoch 88/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6076 - val_mean_absolute_error: 58.6076
# Epoch 89/100
# 2577/2577 [==============================] - 37s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6075 - val_mean_absolute_error: 58.6075
# Epoch 90/100
# 2577/2577 [==============================] - 39s 15ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6088 - val_mean_absolute_error: 58.6088
# Epoch 91/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3165 - mean_absolute_error: 61.3165 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 92/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3161 - mean_absolute_error: 61.3161 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 93/100
# 2577/2577 [==============================] - 35s 13ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6084 - val_mean_absolute_error: 58.6084
# Epoch 94/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6091 - val_mean_absolute_error: 58.6091
# Epoch 95/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6083 - val_mean_absolute_error: 58.6083
# Epoch 96/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3165 - mean_absolute_error: 61.3165 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 97/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3163 - mean_absolute_error: 61.3163 - val_loss: 58.6086 - val_mean_absolute_error: 58.6086
# Epoch 98/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6076 - val_mean_absolute_error: 58.6076
# Epoch 99/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3161 - mean_absolute_error: 61.3161 - val_loss: 58.6090 - val_mean_absolute_error: 58.6090
# Epoch 100/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6076 - val_mean_absolute_error: 58.6076
# Epoch 1/100
# 2577/2577 [==============================] - 41s 15ms/step - loss: 25403.4980 - mean_absolute_error: 25403.4980 - val_loss: 58.6075 - val_mean_absolute_error: 58.6075
# Epoch 2/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3193 - mean_absolute_error: 61.3193 - val_loss: 58.6090 - val_mean_absolute_error: 58.6090
# Epoch 3/100
# 2577/2577 [==============================] - 35s 13ms/step - loss: 61.3185 - mean_absolute_error: 61.3185 - val_loss: 58.6081 - val_mean_absolute_error: 58.6081
# Epoch 4/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3195 - mean_absolute_error: 61.3195 - val_loss: 58.6079 - val_mean_absolute_error: 58.6079
# Epoch 5/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3182 - mean_absolute_error: 61.3182 - val_loss: 58.6102 - val_mean_absolute_error: 58.6102
# Epoch 6/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3185 - mean_absolute_error: 61.3185 - val_loss: 58.6113 - val_mean_absolute_error: 58.6113
# Epoch 7/100
# 2577/2577 [==============================] - 34s 13ms/step - loss: 61.3177 - mean_absolute_error: 61.3177 - val_loss: 58.6081 - val_mean_absolute_error: 58.6081
# Epoch 8/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3173 - mean_absolute_error: 61.3173 - val_loss: 58.6086 - val_mean_absolute_error: 58.6086
# Epoch 9/100
# 2577/2577 [==============================] - 33s 13ms/step - loss: 61.3175 - mean_absolute_error: 61.3175 - val_loss: 58.6088 - val_mean_absolute_error: 58.6088
# Epoch 10/100
# 2577/2577 [==============================] - 37s 15ms/step - loss: 61.3174 - mean_absolute_error: 61.3174 - val_loss: 58.6079 - val_mean_absolute_error: 58.6079
# Epoch 11/100
# 2577/2577 [==============================] - 37s 14ms/step - loss: 61.3166 - mean_absolute_error: 61.3166 - val_loss: 58.6129 - val_mean_absolute_error: 58.6129
# Epoch 12/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3179 - mean_absolute_error: 61.3179 - val_loss: 58.6112 - val_mean_absolute_error: 58.6112
# Epoch 13/100
# 2577/2577 [==============================] - 36s 14ms/step - loss: 61.3179 - mean_absolute_error: 61.3179 - val_loss: 58.6087 - val_mean_absolute_error: 58.6087
# Epoch 14/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3175 - mean_absolute_error: 61.3175 - val_loss: 58.6076 - val_mean_absolute_error: 58.6076
# Epoch 15/100
# 2577/2577 [==============================] - 37s 14ms/step - loss: 61.3168 - mean_absolute_error: 61.3168 - val_loss: 58.6086 - val_mean_absolute_error: 58.6086
# Epoch 16/100
# 2577/2577 [==============================] - 38s 15ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6087 - val_mean_absolute_error: 58.6087
# Epoch 17/100
# 2577/2577 [==============================] - 37s 14ms/step - loss: 61.3164 - mean_absolute_error: 61.3164 - val_loss: 58.6075 - val_mean_absolute_error: 58.6075
# Epoch 18/100
# 2577/2577 [==============================] - 39s 15ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6084 - val_mean_absolute_error: 58.6084
# Epoch 19/100
# 2577/2577 [==============================] - 35s 14ms/step - loss: 61.3162 - mean_absolute_error: 61.3162 - val_loss: 58.6077 - val_mean_absolute_error: 58.6077
# Epoch 20/100
# 2577/2577 [==============================] - 40s 15ms/step - loss: 61.3161 - mean_absolute_error: 61.3161 - val_loss: 58.6076 - val_mean_absolute_error: 58.6076
# Epoch 21/100
#  308/2577 [==>...........................] - ETA: 29s - loss: 54.1946 - mean_absolute_error: 54.1946

# %%
tuner.results_summary()
